# %%
def regiao(estado):
    #definição das regiões 
    
    norte = ['AC', 'AM', 'AP', 'PA', 'RO', 'RR', 'TO']
    
    nordeste = ['AL', 'BA', 'CE', 'MA', 'PB', 'PE', 'PI', 'RN', 'SE']
    
    centro_oeste = ['DF', 'GO', 'MS', 'MT']
    
    sudeste = ['ES', 'MG', 'RJ', 'SP']
    
    sul = ['PR', 'RS', 'SC']
    if estado.upper() in norte:
        return 'N'
    if estado.upper in nordeste:
        return 'NE'
    if estado.upper in centro_oeste:
        return 'CO'
    if estado.upper in sudeste:
        return 'SE'
    if estado.upper() in sul:
        return 'S'
    return 'NA'

# %%
def frete (peso, estado, presente = False):
    """
    Calcula o valor do frete baseado no peso, no estado e se é ou não presente.
    Entrada:
    peso = valor float em gramas
    estado = string com dois caracteres identificando o estado
    presente = Apenas quando for presente= True. Valor padrão.
    Saída:
    Valor em float do custo total do frete

    """
 #calculo do valor do peso
    
    if peso <= 500:
        vp = 15
    elif peso <= 2000:
        vp = 43
    else:
        vp = 103
        
#calculo do valor do estado
    if regiao(estado) == 'NE' or regiao == 'N':
        ve = 50
    if regiao(estado) == 'CO' or regiao == 'S':
        ve = 25
    else:
        ve = 0

#calculo do valor do presente 
    if presente:
        vpr = 10
    else:
        vpr = 0

    return vp+ve+vpr

# %%
peso=float(input("Entre com o valor do peso: "))
estado= input("Entre com o valor do estado: ")
presente= input("É presente <S/N>: ")

if presente in "Ss":
    valor_frete =  frete(peso, estado, True)
else:
    presente = False
    valor_frete =  frete(peso, estado)
print ("O valor total do frete é: " ,valor_frete)
# Out:
# Entre com o valor do peso:  100000
# Entre com o valor do estado:  sp
# É presente <S/N>:  s
# O valor total do frete é:  113

# %%
? conda lista
# Out:
# Object ` conda lista` not found.

# %%
! conda list
# Out:
# # packages in environment at C:\ProgramData\anaconda3:
# #
# # Name                           Version               Build               Channel
# _anaconda_depends                2025.12               py313_mkl_0
# aiobotocore                      2.25.0                py313haa95532_0
# aiodns                           3.5.0                 py313haa95532_1
# aiohappyeyeballs                 2.6.1                 py313haa95532_0
# aiohttp                          3.13.2                py313h02ab6af_0
# aioitertools                     0.12.0                py313haa95532_0
# aiosignal                        1.4.0                 py313haa95532_0
# alabaster                        0.7.16                py313haa95532_0
# altair                           5.5.0                 py313haa95532_0
# anaconda-anon-usage              0.7.5                 pyhb46e38b_100
# anaconda-auth                    0.12.3                py313haa95532_0
# ...

# %%
import random

def determinar_vencedor(escolha_jogador, escolha_computador):
    """Função para determinar quem ganhou a rodada."""
    if escolha_jogador == escolha_computador:
        return "empate"
    elif (escolha_jogador == "pedra" and escolha_computador == "tesoura") or \
         (escolha_jogador == "papel" and escolha_computador == "pedra") or \
         (escolha_jogador == "tesoura" and escolha_computador == "papel"):
        return "jogador"
    else:
        return "computador"

def jogar():
    """Função principal que controla o laço do jogo e a pontuação."""
    print("=== Bem-vindo ao jogo Pedra, Papel e Tesoura! ===")
    nome = input("Digite o seu nome para começar: ").strip()
    
    # Variáveis para armazenar o placar
    vitorias_jogador = 0
    vitorias_computador = 0
    empates = 0
    
    opcoes = ["pedra", "papel", "tesoura"]
    
    # Laço principal do jogo (roda até o jogador decidir parar)
    while True:
        print(f"\nSua vez, {nome}!")
        escolha_jogador = input("Escolha 'pedra', 'papel' ou 'tesoura': ").lower().strip()
        
        # Validação de entrada
        if escolha_jogador not in opcoes:
            print("Escolha inválida! Digite exatamente pedra, papel ou tesoura.")
            continue
            
        escolha_computador = random.choice(opcoes)
        print(f"O Computador escolheu: {escolha_computador}")
        
        # Chamamos a função para ver quem ganhou
        resultado = determinar_vencedor(escolha_jogador, escolha_computador)
        
        if resultado == "empate":
            print("=> Resultado: Deu Empate nesta rodada!")
            empates += 1
        elif resultado == "jogador":
            print(f"=> Resultado: Você venceu esta rodada, {nome}!")
            vitorias_jogador += 1
        else:
            print("=> Resultado: O Computador venceu esta rodada!")
            vitorias_computador += 1
            
        # Pergunta se deseja continuar
        continuar = input("\nQuer continuar jogando? (s/n): ").lower().strip()
        if continuar != 's':
            break # Sai do laço while se a resposta não for 's'

    # Exibição do placar final formatado
    print("\n" + "="*30)
    print(" RESULTADO FINAL ".center(30, "="))
    print("="*30)
    
    # Formatando para que os pontos fiquem alinhados conforme o exemplo
    print(f"Vitórias de {nome:.<14}: {vitorias_jogador}")
    print(f"Vitórias do Computador: {vitorias_computador}")
    print(f"Empates...............: {empates}")
    print("-" * 30)
    
    # Determina o grande campeão
    if vitorias_jogador > vitorias_computador:
        print(f"{nome} foi o grande Campeão(ã)!")
    elif vitorias_computador > vitorias_jogador:
        print("O Computador foi o grande Campeão!")
    else:
        print("O jogo terminou em um grande Empate geral!")
