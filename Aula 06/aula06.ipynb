# %%
idade = int(input("Digite sua idade: "))
carro = input ("Tem carro? <S/N> ")
if idade >=18:
    if carro =="S":
         print ("Pode Dirigir!!")
    else:
        print ("Chama o Uber!!")
else:    
    print ("Chama o Uber!!")
# Out:
# Digite sua idade:  20
# Tem carro? <S/N>  N
# Chama o Uber!!

# %%
idade = int(input("Digite sua idade: "))
carro = input ("Tem carro? <S/N> ")
if(idade >=18) and (carro =="S"):
         print ("Pode Dirigir!!")
else:
        print ("Chama o Uber!!")
# Out:
# Digite sua idade:  20
# Tem carro? <S/N>  s
# Chama o Uber!!

# %%
idade = int(input("Digite sua idade: "))
if idade >=18:
    carro = input ("Tem carro? <S/N> ")
    if carro =="S":
         print ("Pode Dirigir!!")
    print ("Chama o Uber!!")
else:
    print ("Chama o Uber!!")
# Out:
# Digite sua idade:  22
# Tem carro? <S/N>  N
# Chama o Uber!!

# %%
nota1 = float(input("Digite a nota 1:"))
nota2 = float(input("Digite a nota 2: "))
media = (nota1+nota2)/2
print ("A média é igual a:", media)
if media >=5:
    print ("APROVADO")
else:
    print ("REPROVADO")
# Out:
# Digite a nota 1: 2
# Digite a nota 2:  2
# A média é igual a: 2.0
# REPROVADO

# %%
nota1 = float(input("Digite a nota 1:"))
if nota1>=7: 
    nota1 += 0.5 #mais simplificado
nota2 = float(input("Digite a nota 2: "))
if nota2>=7:
    nota2 = nota2 +.0,5    
media = (nota1+nota2)/2
print ("A média é igual a:", media)
if media >=5:
    print ("APROVADO")
else:
    print ("REPROVADO")
# Out:
# Digite a nota 1: 2
# Digite a nota 2:  3
# A média é igual a: 2.5
# REPROVADO

# %%
lado1 = float(input("Digite o primeiro lado do triângulo:"))
lado2 = float (input("Digite o segundo lado do triângulo:"))
base = float (input("Digite a base do triângulo:"))
if (lado1 >= lado2 + base) or (lado2 >= lado1 + base) or (base >= lado1+lado2):
     print ("Não é um triâgulo")
else:
     if (lado1 == lado2 == base) : ##assim só funciona em python 
         print ("Triângulo Equilátero")
     elif (lado1 == lado2) or (lado2 == base) or (lado1 == base) :
                print ("Triângulo Isóceles")
     else:
         print ("Triângulo Escaleno")
# Out:
# Digite o primeiro lado do triângulo: 10
# Digite o segundo lado do triângulo: 10
# Digite a base do triângulo: 10
# Triângulo Equilátero
